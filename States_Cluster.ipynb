# %%
import dill
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
all_means = []
color_code = []

# %%
dill.load_module('/Users/varshinisubramanian/Desktop/CMU/Yttri Lab Research/No Conflict Low Volatility (control)/Mouse Runs (pt. 2)/mouse_9_run.db')

# %%
for i in best_model.means_: 
    all_means.append(i)
    color_code.append(9)

# %%
all_means = np.array(all_means)

# %%
# plotting the state means as a 2d scatterplot, with decision time as a hue

g = sns.scatterplot(
    x=all_means[:, 1], y=all_means[:, 2], hue=all_means[:, 0], s=100, palette="coolwarm"
    #,hue_norm=(0, 1)
    # palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    # height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

g.set(xlabel="Probability of Optimal Action", ylabel="Probability of Reward")
# Out:
# [Text(0.5, 0, 'Probability of Optimal Action'),
#  Text(0, 0.5, 'Probability of Reward')]

# %%
# plotting the state means as a 3d scatterplot

fig = plt.figure()
ax = plt.axes(projection='3d')
sctt = ax.scatter3D(all_means[:, 0], all_means[:, 1], all_means[:, 2], c=color_code, cmap=plt.get_cmap('plasma'), marker='o')
ax.set_ylabel('Probability of Optimal Action')
ax.set_zlabel('Probability of Reward')
ax.set_xlabel("Decision Time")
fig.colorbar(sctt, ax = ax, shrink = 0.5, aspect = 10)
